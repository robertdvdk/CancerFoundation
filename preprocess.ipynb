# %%
import scanpy as sc
import os

# %%
drs = "./DATA/brain/raw_data/train/"
h5ads = []
for file in os.listdir(drs):
    h5ads.append(sc.read_h5ad(drs + file))

# %%
[sum([h5ads[i].n_obs for i in range(len(h5ads))])]
# Out:
# [91822]

# %%
a.X.toarray()[0].max()
# Out:
# 11.862483
